# %%
# Load the libraries
library(tidyverse)

# %%
# Load the datasets
players <- read_csv("https://raw.githubusercontent.com/danial-z/dsci-100-2025w1-group-39/refs/heads/main/players.csv")
sessions <- read_csv("https://raw.githubusercontent.com/danial-z/dsci-100-2025w1-group-39/refs/heads/main/sessions.csv")

players
sessions

# %%
# Inspect the structure of datasets
glimpse(players)
glimpse(sessions)
